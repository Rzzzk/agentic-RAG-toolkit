# %%
import os
import sys
from dotenv import load_dotenv

# Ensure the notebook can import from the 'src' directory
sys.path.append(os.path.abspath("."))

# Load environment variables
load_dotenv()

# Verify your free API key is present
if not os.getenv("GOOGLE_API_KEY"):
    print("Warning: GOOGLE_API_KEY is missing from your environment variables.")
else:
    print("Environment successfully configured!")
# Out:
# Warning: GOOGLE_API_KEY is missing from your environment variables.
